# %% [markdown]
# Week 7 - Distinguishing Sentiments
#
# Pull last 100 tweets from BBC, CBS, CNN, Fox, and NY Times
# Run Vader analysis to determine positive, negative, or neutral sentiment
# Pull into DataFrame the tweet's source account, tex, date, and Vader sentiment scores
# Export Data from DataFrame into CSV File
# Create Scatter Plot and Bar Plot of sentiment data
# Save PNG images from each plot
# Write written description of three observable trends
#
# Citation: Hutto, C.J. & Gilbert, E.E. (2014). VADER: A Parsimonious Rule-based Model for Sentiment Analysis of Social Media Text. Eighth International Conference on Weblogs and Social Media (ICWSM-14). Ann Arbor, MI, June 2014.

# %%
# Dependencies

import json
import time
import tweepy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

from config import (consumer_key, consumer_secret, access_token, access_token_secret)

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Tweet Texts & Timestamps
target_terms = ("BBC", "CBS", "CNN", "FoxNews", "nytimes")

# %%
# List to hold results
results_list = []    
    
# Counter to keep track of the number of tweets retrieved
counter = 0

# %%
# Loop through all target users
for target in target_terms:

    # Variable list for holding Vader Sentiment Results    
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []
    for x in range (5):
    
        # Get all tweets from home feed
        public_tweets = api.user_timeline(target, recent=True, page=x)
        
        # Loop through all tweets
        for tweet in public_tweets:
        
            # Run Vader Analysis on each tweet
            compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]
        
            compound_list.append(compound)
            positive_list.append(pos)
            negative_list.append(neg)
            neutral_list.append(neu)
        
            # Add sentiments for each tweet into an array
            results_list.append({"User": target, 
                           "Source account": tweet["source"],
                           "Date": tweet["created_at"],        
                           "Text": tweet["text"],
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
     
            # Add to counter 
            counter = counter + 1
    
print(results_list)
print("")
# Out:
# [{'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Mon Sep 17 18:04:04 +0000 2018', 'Text': 'University Challenge icons @e_monkman and @Bobby_Seagull road trip around Britain in search of hidden gems of Briti… https://t.co/ehTKqStAoJ', 'Compound': 0.0772, 'Positive': 0.071, 'Negative': 0.929, 'Neutral': 0.0, 'Tweets Ago': 0}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Mon Sep 17 17:04:05 +0000 2018', 'Text': 'Australia has ordered an investigation into the discovery of sewing needles hidden in strawberries.… https://t.co/4VUFTkoOKt', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 1}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Mon Sep 17 16:04:02 +0000 2018', 'Text': 'The finalists of the Comedy Wildlife Photography Awards have been announced! 🐿😂\n https://t.co/fB7n9B6ugV https://t.co/rBl2q4QaDa', 'Compound': 0.6996, 'Positive': 0.326, 'Negative': 0.674, 'Neutral': 0.0, 'Tweets Ago': 2}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Mon Sep 17 15:03:04 +0000 2018', 'Text': 'Who knew Paddington had such a foul mouth?! 😱🐻😂 #QI\n\nhttps://t.co/Si3pPqooX9', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 3}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Mon Sep 17 14:03:05 +0000 2018', 'Text': "The UK's oldest person has seen the outbreak and resolution of two world wars, the sinking of the Titanic, and all… https://t.co/6GLb77FEpO", 'Compound': -0.5574, 'Positive': 0.0, 'Negative': 0.854, 'Neutral': 0.146, 'Tweets Ago': 4}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Mon Sep 17 13:04:04 +0000 2018', 'Text': 'This is truly magical: Sue and her underwater wheelchair. (Via @BBCThree) https://t.co/fKFUb94oM3', 'Compound': 0.4404, 'Positive': 0.209, 'Negative': 0.791, 'Neutral': 0.0, 'Tweets Ago': 5}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Mon Sep 17 12:02:06 +0000 2018', 'Text': 'The Duchess of Sussex has launched her first solo charity project as a royal - a cookbook in support of Grenfell fa… https://t.co/yBj2kdv4rY', 'Compound': 0.7184, 'Positive': 0.292, 'Negative': 0.708, 'Neutral': 0.0, 'Tweets Ago': 6}, {'User': 'BBC', 'Source account': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'Date': 'Mon Sep 17 11:27:23 +0000 2018', 'Text': 'RT @bbcpress: 🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f @larrylamb47 leads cast of TV favourites for new drama #PitchingIn on @BBCWales and @BBCOne daytime: https://t.co/Say…', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 7}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Mon Sep 17 11:03:04 +0000 2018', 'Text': '🌟🌠✨ The International Dark Sky Association has named Wales as a dark skies world leader... \n\nhttps://t.co/6cMHSt3mPT', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 8}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Mon Sep 17 10:03:05 +0000 2018', 'Text': 'Meet Vera, a 102-year-old Manchester City mascot. 💙️⚽️\n\nhttps://t.co/TRLp6M4m6G', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 9}, {'User': 'BBC', 'Source account': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'Date': 'Mon Sep 17 09:04:06 +0000 2018', 'Text': 'Your week, as told by @louistheroux...\n\nhttps://t.co/S4y4TzziDY', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': ...

# %%
#Convert to DataFrame

results_list = pd.DataFrame.from_dict(results_list)
results_list
# Out:
#      Compound                            Date  Negative  Neutral  Positive  \
# 0      0.0772  Mon Sep 17 18:04:04 +0000 2018     0.929    0.000     0.071
# 1      0.0000  Mon Sep 17 17:04:05 +0000 2018     1.000    0.000     0.000
# 2      0.6996  Mon Sep 17 16:04:02 +0000 2018     0.674    0.000     0.326
# 3      0.0000  Mon Sep 17 15:03:04 +0000 2018     1.000    0.000     0.000
# 4     -0.5574  Mon Sep 17 14:03:05 +0000 2018     0.854    0.146     0.000
# 5      0.4404  Mon Sep 17 13:04:04 +0000 2018     0.791    0.000     0.209
# 6      0.7184  Mon Sep 17 12:02:06 +0000 2018     0.708    0.000     0.292
# 7      0.0000  Mon Sep 17 11:27:23 +0000 2018     1.000    0.000     0.000
# 8      0.0000  Mon Sep 17 11:03:04 +0000 2018     1.000    0.000     0.000
# 9      0.0000  Mon Sep 17 10:03:05 +0000 2018     1.000    0.000     0.000
# 10     0.0000  Mon Sep 17 09:04:06 +0000 2018     1.000    0.000     0.000
# 11     0.5994  Mon Sep 17 08:02:03 +0000 2018     0.755    0.000     0.245
# 12     0.5719  Mon Sep 17 07:31:08 +0000 2018     0.802    0.000     0.198
# 13     0.0000  Mon Sep 17 07:03:05 +0000 2018     1.000    0.000     0.000
# 14     0.4767  Sun Sep 16 19:17:07 +0000 2018     0.838    0.000     0.162
# 15     0.0000  Sun Sep 16 17:04:06 +0000 2018     1.000    0.000     0.000
# 16     0.0000  Sun Sep 16 16:02:03 +0000 2018     1.000    0.000     0.000
# 17     0.0000  Sun Sep 16 15:03:04 +0000 2018     1.000    0.000     0.000
# 18    -0.1531  Sun Sep 16 14:04:05 +0000 2018     0.676    0.176     0.149
# 19     0.0000  Sun Sep 16 14:01:39 +0000 2018     1.000    0.000     0.000
# 27   RT @bbcpress: 🏴󠁧󠁢󠁷󠁬󠁳󠁿 @larrylamb47 leads cast ...          27      BBC
# 28   🌟🌠✨ The International Dark Sky Association has...          28      BBC
# 29   Meet Vera, a 102-year-old Manchester City masc...          29      BBC
# ..                                                 ...         ...      ...
# 470  "It's easy to say, 'I love God,' but put on yo...         470  nytimes
# 471  There's no doubt Tesla and Elon Musk have plen...         471  nytimes
# 472  The man stood casually on the subway tracks, h...         472  nytimes
# 473  North Carolina is facing a statewide crisis as...         473  nytimes
# 474  Molly Kelly fended off a challenge from the le...         474  nytimes
# 475  Soon-Yi Previn said starting a relationship wi...         475  nytimes
# 476  There has been another huge misinformation cam...         476  nytimes
# 477  A woman who accuses Supreme Court nominee Bret...         477  nytimes
# 478  Michael Bloomberg may run for President as a D...         478  nytimes
# 479  Morning Briefing: Here's what you need to know...         479  nytimes
# 480  RT @nytimesworld: Museums are where we tell st...         480  nytimes
# 481  "North Korea will highlight the discrepancy: '...         481  nytimes
# 482  RT @JackEwingNYT: I still say the evolution of...         482  nytimes
# 483  7 years after @sweden began giving ordinary Sw...         483  nytimes
# 484  The first full-dress retrospective in North Am...         484  nytimes
# 485  How do companies regain public trust after som...         485  nytimes
# 486  The Russia spy scandal has claimed another vic...         486  nytimes
# 487  RT @stevenleemyers: In Yangjiang, broken glass...         487  nytimes
# 488  More than 230,000 infants were treated in emer...         488  nytimes
# 489  The air travel disruptions that rippled across...         489  nytimes
# 490  3 concrete tips that will help you become a mo...         490  nytimes
# 491  As President Trump ratchets up the trade war w...         491  nytimes
# 492  RT @davidenrich: This is my favorite page in t...         492  nytimes
# 493  A day after Typhoon Mangkhut tore through the ...         493  nytimes
# 494  U.S. prosecutors have quietly dismissed charge...         494  nytimes
# 495  After 5 elections over 17 years, costing about...         495  nytimes
# 496  With the deal for Time, the Benioffs have pick...         496  nytimes
# 497  Eliud Kipchoge of Kenya broke the world record...         497  nytimes
# 498  Dozens of Times journalists are covering the p...         498  nytimes
# 499  Maps of Hurricane Florence's impact tracking t...         499  nytimes
#
# [500 rows x 9 columns]

# %%
#Set News source as User Index

results_list = results_list.set_index("User")
results_list.head()
# Out:
#       Compound                            Date  Negative  Neutral  Positive  \
# User
# BBC     0.0772  Mon Sep 17 18:04:04 +0000 2018     0.929    0.000     0.071
# BBC     0.0000  Mon Sep 17 17:04:05 +0000 2018     1.000    0.000     0.000
# BBC     0.6996  Mon Sep 17 16:04:02 +0000 2018     0.674    0.000     0.326
# BBC     0.0000  Mon Sep 17 15:03:04 +0000 2018     1.000    0.000     0.000
# BBC    -0.5574  Mon Sep 17 14:03:05 +0000 2018     0.854    0.146     0.000
#
#                                          Source account  \
# User
# BBC   <a href="http://www.socialflow.com" rel="nofol...
# BBC   <a href="http://www.socialflow.com" rel="nofol...
# BBC   <a href="http://www.socialflow.com" rel="nofol...
# BBC   <a href="http://www.socialflow.com" rel="nofol...
# BBC   <a href="http://www.socialflow.com" rel="nofol...
#
#                                                    Text  Tweets Ago
# User
# BBC   University Challenge icons @e_monkman and @Bob...           0
# BBC   Australia has ordered an investigation into th...           1
# BBC   The finalists of the Comedy Wildlife Photograp...           2
# BBC   Who knew Paddington had such a foul mouth?! 😱🐻...           3
# BBC   The UK's oldest person has seen the outbreak a...           4

# %%
# Save to DataFrame
results_list.to_csv("../twitter_sentiment_recent.csv", index=False)

# %%
# Target News Twitter Accounts
target = ("BBC", "CBS", "CNN", "FoxNews", "nytimes")

# List to hold results
results_list = []

# Loop through all target users
for target in target:

    # Variable for holding the oldest tweet
    oldest_tweet = None

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []

    # Loop through 10 times
    for x in range(1):

        # Run search around each tweet
        public_tweets = api.search(
            target, count=100, result_type="recent")

        # Loop through all tweets
        for tweet in public_tweets["statuses"]:

                # Run Vader Analysis on each tweet
                results = analyzer.polarity_scores(tweet["text"])
                compound = results["compound"]
                pos = results["pos"]
                neu = results["neu"]
                neg = results["neg"]

                # Add each value to the appropriate list
                compound_list.append(compound)
                positive_list.append(pos)
                negative_list.append(neg)
                neutral_list.append(neu)
                
        # Set the new oldest_tweet value
        oldest_tweet = tweet["id"] - 1

    # Store the Average Sentiments
    sentiment_overall = {
        "News": target,
        "Compound": np.mean(compound_list),
        "Positive": np.mean(positive_list),
        "Neutral": np.mean(negative_list),
        "Negative": np.mean(neutral_list),
    }

    # Print the Sentiments
    print(sentiment_overall)
    print()
    
    # Append twitter to 'results_list'
    results_list.append(sentiment_overall)
# Out:
# {'News': 'BBC', 'Compound': 0.021844999999999993, 'Positive': 0.07412999999999999, 'Neutral': 0.062349999999999996, 'Negative': 0.86351}
#
# {'News': 'CBS', 'Compound': 0.172075, 'Positive': 0.12394999999999999, 'Neutral': 0.04938, 'Negative': 0.8266899999999999}
#
# {'News': 'CNN', 'Compound': 0.07276400000000001, 'Positive': 0.07793, 'Neutral': 0.048440000000000004, 'Negative': 0.8736199999999998}
#
# {'News': 'FoxNews', 'Compound': -0.16028900000000001, 'Positive': 0.0516, 'Neutral': 0.11134000000000001, 'Negative': 0.83702}
#
# {'News': 'nytimes', 'Compound': 0.007576, 'Positive': 0.06727999999999999, 'Neutral': 0.060090000000000005, 'Negative': 0.8726200000000002}

# %%
#Convert to DataFrame

sentiment_overall = {"News": target,
            "Compound": compound_list,
            "Positive": positive_list,
            "Neutral": neutral_list,
            "Negative": negative_list
          }
pd.DataFrame(results_list)
# Out:
#    Compound  Negative  Neutral     News  Positive
# 0  0.021845   0.86351  0.06235      BBC   0.07413
# 1  0.172075   0.82669  0.04938      CBS   0.12395
# 2  0.072764   0.87362  0.04844      CNN   0.07793
# 3 -0.160289   0.83702  0.11134  FoxNews   0.05160
# 4  0.007576   0.87262  0.06009  nytimes   0.06728
